# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

rng = np.random.default_rng(42)

paths = 50
points = 1000

mu, sigma = 0.0, 1.0

Z = rng.normal(mu, sigma, (paths, points))

interval = [0.0, 1.0]
dt = (interval[1] - interval[0]) / (points - 1)

t_axis = np.linspace(interval[0], interval[1], points)

W = np.zeros((paths, points))
for idx in range(points - 1):
    real_idx = idx + 1
    W[:, real_idx] = W[:, real_idx - 1] + np.sqrt(dt) * Z[:, idx]

fig, ax = plt.subplots(1, 1, figsize=(12, 8))
for path in range(paths):
    ax.plot(t_axis, W[path, :])
ax.set_title("Standard Brownian Motion sample paths")
ax.set_xlabel("Time")
ax.set_ylabel("Asset Value")
plt.show()

# %%
Z
# Out:
# array([[ 0.30471708, -1.03998411,  0.7504512 , ...,  0.12117795,
#          0.13076419,  0.82375313],
#        [-0.05928265, -0.72928694, -0.41447307, ..., -0.09154002,
#         -0.53082183,  2.21415262],
#        [-0.45195098, -0.66587771,  0.43400982, ...,  2.33102467,
#          0.81944757, -0.33412073],
#        ...,
#        [ 0.54271853, -0.64883525, -1.06339493, ...,  1.44045621,
#         -0.90987006,  0.44410301],
#        [-0.20805659,  0.10616819, -0.24589265, ..., -0.54336426,
#         -1.17025498, -1.72314521],
#        [-0.55567297,  1.58997862,  0.96910996, ...,  0.39849184,
#          1.35827139,  1.39547596]])

# %%
total = 0
for i in range(1,5):
    total += i
    print(total)
# Out:
# 1
# 3
# 6
# 10
